# %% [markdown]
# # Working With Play by Play
#
# Working with play by play can be interesting work in that there's a lot of unknown types of data as well as parsing of strings. In addition, there a ton of cool things that can be done with play be play like sending the feed into a pub\sub model so other systems can interact with it, build your own UI, or a whole host of other ideas.
#
# The goal of this notebook is to walk through the play by play feed examining data such as
#
# 1. `EVENTMSGTYPE` which provides the play type (e.g. FIELD_GOAL_MADE, FIELD_GOAL_MISSED, TIMEOUT, PERIOD_BEGIN, etc.)
# 2. `EVENTMSGACTIONTYPE`which provides a subcatagorization of `EVENTMSGTYPE` (e.g. REVERSE_LAYUP, 3PT_JUMP_SHOT, HOOK_SHOT, etc.)
#
# This notebook builds on top of the following notebooks: [Finding Games](notebook2.ipynb), [Basics Notebook](Basics.ipynb), and of course, dives into `PlayByPlay` endpoint. Note that the `PlayByPlayV2` endpoint is an extension of `PlayByPlay`.
#
#
# So with that...let's get started!
#
# The goals are
# 1. Get the last game the Pacers played (maybe we'll get lucky and get a current game)
# 2. Examine the feed and the fields that are returned
# 3. See how Regex can be applied to the play by play
# 3. Dynamically build a unique list of NBA Player Actions Events using EVENTMSGACTIONTYPE
# 4. See what's hiding in the feed...need to get those BLOCKS from the shot blockers!

# %% [markdown]
# # Let's get started and jump into the game!
#
# First thing's first...get the Pacers team_id

# %%
#Get the Pacers team_id
from nba_api.stats.static import teams

nba_teams = teams.get_teams()

# Select the dictionary for the Pacers, which contains their team ID
pacers = [team for team in nba_teams if team['abbreviation'] == 'PHX'][0]
pacers_id = pacers['id']
print(f'pacers_id: {pacers_id}')
# Out:
# pacers_id: 1610612756

# %% [markdown]
# Searching through the games and get the most recent Pacers game_id

# %%
# Query for the last regular season game where the Pacers were playing
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=pacers_id,
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']
game = games[0]
game_id = game['GAME_ID']
game_matchup = game['MATCHUP']

print(f'Searching through {len(games)} game(s) for the game_id of {game_id} where {game_matchup}')
# Out:
# Searching through 41 game(s) for the game_id of 0022400586 where PHX @ DET

# %% [markdown]
# # Retrieving the play by play data
# Now that we've got a game_id, let's pull some play by play data

# %%
# Query for the play by play of that most recent regular season game
from nba_api.stats.endpoints import playbyplay
df = playbyplay.PlayByPlay(game_id).get_data_frames()[0]
df.head(100) #just looking at the head of the data
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0   0022400586         2            12                   0       1
# 1   0022400586         4            10                   0       1
# 2   0022400586         7             2                  79       1
# 3   0022400586         8             4                   0       1
# 4   0022400586         9             2                 101       1
# 5   0022400586        10             4                   0       1
# 6   0022400586        11             1                   1       1
# 7   0022400586        13             1                   1       1
# 8   0022400586        15             2                   1       1
# 89      4:29 PM         2:40
# 90      4:29 PM         2:40
# 91      4:29 PM         2:40
# 92      4:30 PM         2:40
# 93      4:31 PM         2:40
# 94      4:31 PM         2:40
# 95      4:32 PM         2:40
# 96      4:33 PM         2:20
# 97      4:33 PM         2:17
# 98      4:33 PM         2:09
# 99      4:33 PM         1:46
#
#                                               HOMEDESCRIPTION  \
# 0                                                        None
# 1                    Jump Ball Duren vs. Plumlee: Tip to Dunn
# 2                                                        None
# 3                                 Duren REBOUND (Off:0 Def:1)
# 4            MISS Hardaway Jr. 11' Driving Floating Jump Shot
# 5                                                        None
# 6                                                        None
# 7         Harris 24' 3PT Jump Shot (3 PTS) (Cunningham 1 AST)
# 8                                                        None
# 9                                Harris REBOUND (Off:0 Def:1)
# 10           Harris 25' 3PT Running Pull-Up Jump Shot (6 PTS)
# 11                                                       None
# 12              MISS Cunningham 8' Driving Floating Jump Shot
# 13                           Cunningham REBOUND (Off:1 Def:0)
# 14                              MISS Harris 27' 3PT Jump Shot
# 15                                Duren REBOUND (Off:1 Def:1)
# 16              MISS Cunningham 7' Driving Floating Jump Shot
# 17                                                       None
# 18                        Duren S.FOUL (P1.T1) (J.Goldenberg)
# 19                                                       None
# 20                                                       None
# 21                                                       None
# 22                  MISS Hardaway Jr. 19' Step Back Jump Shot
# 23                                                       None
# 24                                                       None
# 25  Harris 9' Turnaround Jump Shot (8 PTS) (Cunningham 2 AST)
# 26                          Thompson P.FOUL (P1.T2) (J.Goble)
# 27                                   Cunningham STEAL (1 STL)
# 28   Hardaway Jr. 6' Running Layup (2 PTS) (Cunningham 3 AST)
# 29                                                       None
# 30                     Hardaway Jr. Free Throw 1 of 1 (3 PTS)
# 31                                                       None
# 32                                                       None
# 33                                                       None
# 34                                                       None
# 35                       Cunningham Free Throw 1 of 2 (1 PTS)
# 36                          MISS Cunningham Free Throw 2 of 2
# 37                                                       None
# 38                                                       None
# 39                                                       None
# 40                Cunningham 27' 3PT Pullup Jump Shot (4 PTS)
# 41                             Duren S.FOUL (P2.T3) (J.Ralls)
# 42                  PISTONS Timeout: Regular (Full 1 Short 0)
# 43                                     SUB: Stewart FOR Duren
# 44                                                       None
# 45                                                       None
# 46                                                       None
# 47                   MISS Cunningham 26' 3PT Pullup Jump Shot
# 48                                                       None
# 49                                                       None
# 50                    MISS Cunningham 6' Turnaround Jump Shot
# 51                                                       None
# 52                                                       None
# 53                                  SUB: Beasley FOR Thompson
# 54                       Cunningham Bad Pass Turnover (P1.T1)
# 55                                                       None
# 56                           Cunningham REBOUND (Off:1 Def:1)
# 57         Beasley 4' Running Dunk (2 PTS) (Cunningham 4 AST)
# 58                                                       None
# 59                                                       None
# 60                        MISS Hardaway Jr. 26' 3PT Jump Shot
# 61                                                       None
# 62                                                       None
# 63                                                       None
# 64                                                       None
# 65                       Stewart OFF.Foul (P1) (J.Goldenberg)
# 66                    Stewart Offensive Foul Turnover (P1.T2)
# 67                           SUB: Fontecchio FOR Hardaway Jr.
# 68                                                       None
# 69                        Cunningham P.FOUL (P1.T4) (J.Goble)
# 70                                                       None
# 71                              MISS Harris 28' 3PT Jump Shot
# 72                                                       None
# 73                                                       None
# 74                               Harris REBOUND (Off:0 Def:2)
# 75                                                       None
# 76                       Cunningham Free Throw 1 of 2 (5 PTS)
# 77                       Cunningham Free Throw 2 of 2 (6 PTS)
# 78                                                       None
# 79                           Fontecchio REBOUND (Off:0 Def:1)
# 80                           MISS Harris 18' Pullup Jump Shot
# 81                                                       None
# 82                                                       None
# 83                          MISS Cunningham 26' 3PT Jump Shot
# 84                                                       None
# 85                                                       None
# 86       Beasley 26' 3PT Jump Shot (5 PTS) (Cunningham 5 AST)
# 87                        Fontecchio S.FOUL (P1.PN) (J.Goble)
# 88                                                       None
# 89                                                       None
# 90                                                       None
# 91                        Harris Free Throw Technical (9 PTS)
# 92                                                       None
# 93                                 SUB: Sasser FOR Cunningham
# 94                                                       None
# 95                                                       None
# 96                      MISS Beasley 31' 3PT Pullup Jump Shot
# 97                                                       None
# 98                                                       None
# 99        Harris 9' Driving Hook Shot (11 PTS) (Sasser 1 AST)
#
#                    NEUTRALDESCRIPTION  \
# 0   Start of 1st Period (4:10 PM EST)
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# 5                                None
# 6                                None
# 7                                None
# 8                                None
# 9                                None
# 10                               None
# 11                               None
# 12                               None
# 13                               None
# 14                               None
# 15                               None
# 16                               None
# 17                               None
# 18                               None
# 19                               None
# 20                               None
# 21                               None
# 22                               None
# 23                               None
# 24                               None
# 25                               None
# 26                               None
# 27                               None
# 28                               None
# 29                               None
# 30                               None
# 31                               None
# 32                               None
# 33                               None
# 34                               None
# 35                               None
# 36                               None
# 37                               None
# 38                               None
# 39                               None
# 40                               None
# 41                               None
# 42                               None
# 43                               None
# 44                               None
# 45                               None
# 46                               None
# 47                               None
# 48                               None
# 49                               None
# 50                               None
# 51                               None
# 52                               None
# 53                               None
# 54                               None
# 55                               None
# 56                               None
# 57                               None
# 58                               None
# 59                               None
# 60                               None
# 61                               None
# 62                               None
# 63                               None
# 64                               None
# 65                               None
# 66                               None
# 67                               None
# 68                               None
# 69                               None
# 70                               None
# 71                               None
# 72                               None
# 73                               None
# 74                               None
# 75                               None
# 76                               None
# 77                               None
# 78                               None
# 79                               None
# 80                               None
# 81                               None
# 82                               None
# 83                               None
# 84                               None
# 85                               None
# 86                               None
# 87                               None
# 88                               None
# 89                               None
# 90                               None
# 91                               None
# 92                               None
# 93                               None
# 94                               None
# 95                               None
# 96                               None
# 97                               None
# 98                               None
# 99                               None
#
#                                            VISITORDESCRIPTION    SCORE  \
# 0                                                        None     None
# 1                                                        None     None
# 2                            MISS Booker 17' Pullup Jump Shot     None
# 3                                                        None     None
# 4                                                        None     None
# 5                               Plumlee REBOUND (Off:0 Def:1)     None
# 6                   Dunn 3PT Jump Shot (3 PTS) (Durant 1 AST)    3 - 0
# 7                                                        None    3 - 3
# 8                                   MISS Durant 3PT Jump Shot     None
# 9                                                        None     None
# 10                                                       None    3 - 6
# 11         Dunn 1' Cutting Layup Shot (5 PTS) (Plumlee 1 AST)    5 - 6
# 12                                       Durant BLOCK (1 BLK)     None
# 13                                                       None     None
# 14                                                       None     None
# 15                                                       None     None
# 16                                                       None     None
# 17                              Plumlee REBOUND (Off:0 Def:2)     None
# 18                                                       None     None
# 19                              MISS Durant Free Throw 1 of 2     None
# 20                                               Suns Rebound     None
# 21                           Durant Free Throw 2 of 2 (1 PTS)    6 - 6
# 22                                                       None     None
# 23                                 Dunn REBOUND (Off:0 Def:1)     None
# 24   Booker 25' 3PT Step Back Jump Shot (3 PTS) (Jones 1 AST)    9 - 6
# 25                                                       None    9 - 8
# 26                                                       None     None
# 27                           Booker Bad Pass Turnover (P1.T1)     None
# 28                                                       None   9 - 10
# 29                            Booker S.FOUL (P1.T1) (J.Goble)     None
# 30                                                       None   9 - 11
# 31                           MISS Booker 16' Pullup Jump Shot     None
# 32                                 Dunn REBOUND (Off:1 Def:1)     None
# 33                              Dunn 4' Putback Layup (7 PTS)  11 - 11
# 34                      Plumlee S.FOUL (P1.T2) (J.Goldenberg)     None
# 35                                                       None  11 - 12
# 36                                                       None     None
# 37                                  SUB: Richards FOR Plumlee     None
# 38                                Jones REBOUND (Off:0 Def:1)     None
# 39                         Durant 9' Pullup Jump Shot (3 PTS)  13 - 12
# 40                                                       None  13 - 15
# 41                                                       None     None
# 42                                                       None     None
# 43                                                       None     None
# 44                            MISS Richards Free Throw 1 of 2     None
# 45                                               Suns Rebound     None
# 46                         Richards Free Throw 2 of 2 (1 PTS)  14 - 15
# 47                                                       None     None
# 48                             Richards REBOUND (Off:0 Def:1)     None
# 49                             Jones 7' Driving Layup (2 PTS)  16 - 15
# 50                                                       None     None
# 51                                Jones REBOUND (Off:0 Def:2)     None
# 52  Durant Out of Bounds - Bad Pass Turnover Turnover (P1.T2)     None
# 53                                                       None     None
# 54                                       Durant STEAL (1 STL)     None
# 55              MISS Durant 26' 3PT Running Pull-Up Jump Shot     None
# 56                                                       None     None
# 57                                                       None  16 - 17
# 58                           Jones Backcourt Turnover (P1.T3)     None
# 59                                       SUB: Allen FOR Jones     None
# 60                                                       None     None
# 61                             Richards REBOUND (Off:0 Def:2)     None
# 62                    MISS Dunn 7' Driving Floating Jump Shot     None
# 63                             Richards REBOUND (Off:1 Def:2)     None
# 64           Dunn 24' 3PT Jump Shot (10 PTS) (Richards 1 AST)  19 - 17
# 65                                                       None     None
# 66                                                       None     None
# 67                                                       None     None
# 68                                      SUB: O'Neale FOR Dunn     None
# 69                                                       None     None
# 70            Durant Out of Bounds Lost Ball Turnover (P2.T4)     None
# 71                                                       None     None
# 72                              O'Neale REBOUND (Off:0 Def:1)     None
# 73                              MISS Durant 24' 3PT Jump Shot     None
# 74                                                       None     None
# 75                           O'Neale S.FOUL (P1.T3) (J.Goble)     None
# 76                                                       None  19 - 18
# 77                                                       None  19 - 19
# 78                        MISS Durant 13' Step Back Jump Shot     None
# 79                                                       None     None
# 80                                       Durant BLOCK (2 BLK)     None
# 81                             Richards REBOUND (Off:1 Def:3)     None
# 82                         Booker 8' Pullup Jump Shot (5 PTS)  21 - 19
# 83                                                       None     None
# 84                              O'Neale REBOUND (Off:0 Def:2)     None
# 85         Booker 4' Cutting Layup Shot (7 PTS) (Allen 1 AST)  23 - 19
# 86                                                       None  23 - 22
# 87                                                       None     None
# 88                           Booker Free Throw 1 of 2 (8 PTS)  24 - 22
# 89                           Booker Free Throw 2 of 2 (9 PTS)  25 - 22
# 90                          Richards T.FOUL (P0.T3) (J.Goble)     None
# 91                                                       None  25 - 23
# 92                      Suns Timeout: Regular (Reg.1 Short 0)     None
# 93                                                       None     None
# 94                                      SUB: Morris FOR Allen     None
# 95                                     SUB: Allen FOR O'Neale     None
# 96                                                       None     None
# 97                               Booker REBOUND (Off:0 Def:1)     None
# 98                           Booker 6' Driving Layup (11 PTS)  27 - 23
# 99                                                       None  27 - 25
#
#    SCOREMARGIN
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6           -3
# 7          TIE
# 8         None
# 9         None
# 10           3
# 11           1
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21         TIE
# 22        None
# 23        None
# 24          -3
# 25          -1
# 26        None
# 27        None
# 28           1
# 29        None
# 30           2
# 31        None
# 32        None
# 33         TIE
# 34        None
# 35           1
# 36        None
# 37        None
# 38        None
# 39          -1
# 40           2
# 41        None
# 42        None
# 43        None
# 44        None
# 45        None
# 46           1
# 47        None
# 48        None
# 49          -1
# 50        None
# 51        None
# 52        None
# 53        None
# 54        None
# 55        None
# 56        None
# 57           1
# 58        None
# 59        None
# 60        None
# 61        None
# 62        None
# 63        None
# 64          -2
# 65        None
# 66        None
# 67        None
# 68        None
# 69        None
# 70        None
# 71        None
# 72        None
# 73        None
# 74        None
# 75        None
# 76          -1
# 77         TIE
# 78        None
# 79        None
# 80        None
# 81        None
# 82          -2
# 83        None
# 84        None
# 85          -4
# 86          -1
# 87        None
# 88          -2
# 89          -3
# 90        None
# 91          -2
# 92        None
# 93        None
# 94        None
# 95        None
# 96        None
# 97        None
# 98          -4
# 99          -2

# %% [markdown]
# Optional: Dataframes can become large. In pandas you can set some options to make it more visible if needed

# %%
#Since the datset is fairly large you'll see plenty of elipses(...). 
#If that's the case, you can set the following options to expand the data 
#You can adjust these as you'd like
import pandas
pandas.set_option('display.max_colwidth',250)
pandas.set_option('display.max_rows',250)

# %% [markdown]
# Some of the most valuable fields of `PlayByPlay`are the following:
# `EVENTMSGTYPE`
# `EVENTMSGACTIONTYPE`
# `HOMEDESCRIPTION`
# and `VISITORDESCRIPTION`.
#
# `EVENTMSGTYPE` gives us the type of event that has occurred. This can vary per game. This is why finding these and placing them into an Enum or other type structure is a good idea.

# %%
#List unique values in the df['EVENTMSGTYPE'] colum
print(f'EVENTMSGTYPE: {sorted(df.EVENTMSGTYPE.unique())}')
# Out:
# EVENTMSGTYPE: [1, 2, 3, 4, 5, 6, 8, 9, 10, 12, 13, 18]

# %%
#For quick refernce, here's an Enum for `EVENTMSGTYPE`
#This list may be incomplete as a thourogh play by play scan is necessary

from enum import Enum

class EventMsgType(Enum):
    FIELD_GOAL_MADE = 1
    FIELD_GOAL_MISSED = 2
    FREE_THROWfree_throw_attempt = 3
    REBOUND = 4
    TURNOVER = 5
    FOUL = 6
    VIOLATION = 7
    SUBSTITUTION = 8
    TIMEOUT = 9
    JUMP_BALL = 10
    EJECTION = 11
    PERIOD_BEGIN = 12
    PERIOD_END = 13

# %% [markdown]
# Using the `EVENTMSGTYPE` field we can begin to examine the event types to see what typical values will be in the `EVENTMSGACTIONTYPE` `HOMEDESCRIPTION` and `VISITORDESCRIPTION` fields.

# %%
#### pull the data for a specfic EVENTMSGTYPE
df.loc[df['EVENTMSGTYPE'] == 1].head() #hint: use the EVENTMSGTYPE values above to see different data
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 6   0022400586        11             1                   1       1
# 7   0022400586        13             1                   1       1
# 10  0022400586        17             1                 103       1
# 11  0022400586        18             1                  98       1
# 24  0022400586        34             1                  80       1
#
#    WCTIMESTRING PCTIMESTRING  \
# 6       4:11 PM        11:19
# 7       4:11 PM        10:56
# 10      4:12 PM        10:31
# 11      4:12 PM        10:17
# 24      4:14 PM         9:00
#
#                                         HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 6                                                  None               None
# 7   Harris 24' 3PT Jump Shot (3 PTS) (Cunningham 1 AST)               None
# 10     Harris 25' 3PT Running Pull-Up Jump Shot (6 PTS)               None
# 11                                                 None               None
# 24                                                 None               None
#
#                                           VISITORDESCRIPTION  SCORE  \
# 6                  Dunn 3PT Jump Shot (3 PTS) (Durant 1 AST)  3 - 0
# 7                                                       None  3 - 3
# 10                                                      None  3 - 6
# 11        Dunn 1' Cutting Layup Shot (5 PTS) (Plumlee 1 AST)  5 - 6
# 24  Booker 25' 3PT Step Back Jump Shot (3 PTS) (Jones 1 AST)  9 - 6
#
#    SCOREMARGIN
# 6           -3
# 7          TIE
# 10           3
# 11           1
# 24          -3

# %% [markdown]
# Now that we've seen what the output of `EVENTMSGTYPE` is, let's dig into `EVENTMSGACTIONTYPE`.
#
# For this next exercise, let's pull all unique `EVENTMSGACTIONTYPE` values for `EVENTMSGTYPE = 1`
#
# _Note: `EVENTMSGACTIONTYPE` ids have a very loose correlation to `EVENTMSGTYPE` ids. This means that `EVENTMSGTYPE` ids share some of the same `EVENTMSGACTIONTYPE` ids. This allows the NBA to have a 'Missed Field Goal' share the same '3PT Jump Shot' with a 'Made Field Goal'. Now, that being said, they are not always unique. We'll see this towards the end._

# %%
#List unique values in the df['EVENTMSGTYPE'] column
emt_df = df.loc[df['EVENTMSGTYPE'] == 1]
print(f'EVENTMSGACTIONTYPE: {sorted(emt_df.EVENTMSGACTIONTYPE.unique())}')
# Out:
# EVENTMSGACTIONTYPE: [1, 6, 9, 41, 44, 47, 50, 57, 63, 72, 75, 78, 79, 80, 83, 86, 87, 93, 97, 98, 100, 101, 103, 107, 108]

# %% [markdown]
# # So how do we know what each `EVENTMSGACTIONTYPE` is?
#
# Let the fun begin.
#
# Apply some regular expressions, that are `EVENTMSGTYPE` specific, against `HOMEDECSRIPTION` and `VISITORDESCRIPTION` while keeping track of the `EVENTMSGACTIONTYPE`.
#
# To see the regular expressions in action, take the example listed in the comments, along with the regex, and head on over to https://regex101.com/ or your favorite regex interative tool.

# %% [markdown]
# # `EVENTMSGTYPE == 1`
# The following regex expression `'(\s{2}|\' )([\w+ ]*)` will look for the type of basket within the `VISITORDESCRIPTION` or `HOMEDESCRIPTION` and tie that to the `EVENTMSGACTIONTYPE`.
#
# Example: Given a `VISITORDESCRIPTION == 'Young Cutting Layup Shot (2 PTS) (Collison 1 AST)'` and a `EVENTMSGACTIONTYPE = 98`, the code will produce an output of `CUTTING_LAYUP_SHOT = 99`
#
# Let's see it in action...
#
# _Note: The regex may need to be adjusted over time to account for changes in the data_

# %%
#Mapping out all of the EventMsgActionTypes for EventMsgType 1
import re
import operator

#the following expression is specific to EventMsgType 1
p = re.compile('(\s{2}|\' )([\w+ ]*)')

#get the PlayByPlay data from the Pacers game_id
plays = playbyplay.PlayByPlay(game_id).get_normalized_dict()['PlayByPlay']

#declare a few variables
description = ''
event_msg_action_types = {}

#loop over the play by play data
for play in plays:
    if play['EVENTMSGTYPE'] == 1:
        description = play['HOMEDESCRIPTION'] if play['HOMEDESCRIPTION'] is not None else play['VISITORDESCRIPTION']
        if description is not None:
            #do a bit of searching(regex) and a little character magic: underscores and upper case
            event_msg_action = re.sub(' ', '_', p.search(description).groups()[1].rstrip()).upper()
            #Add it to our dictionary
            event_msg_action_types[event_msg_action] = play['EVENTMSGACTIONTYPE']
            
#sort it all
event_msg_action_types = sorted(event_msg_action_types.items(), key=operator.itemgetter(0))

#output a class that we could plug into our code base
for action in event_msg_action_types:
    print(f'\t{action[0]} = {action[1]}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 21
#      18 description = play['HOMEDESCRIPTION'] if play['HOMEDESCRIPTION'] is not None else play['VISITORDESCRIPTION']
#      19 if description is not None:
#      20     #do a bit of searching(regex) and a little character magic: underscores and upper case
# ---> 21     event_msg_action = re.sub(' ', '_', p.search(description).groups()[1].rstrip()).upper()
#      22     #Add it to our dictionary
#      23     event_msg_action_types[event_msg_action] = play['EVENTMSGACTIONTYPE']
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %% [markdown]
# # `EVENTMSGTYPE == 2`
# We'll reuse the regex expression `(\s{2}|' )([\w+ ]*)` from `EVENTMSGTYPE == 1` for `EVENTMSGTYPE == 2`. EventMsgType 2 are missed field goals. Again, it'll look for the type of basket within the `VISITORDESCRIPTION` or `HOMEDESCRIPTION` and tie that to the `EVENTMSGACTIONTYPE`.
#
# Example: Given a `HOMEDESCRIPTION == 'MISS Collison 24' 3PT Jump Shot'` and a `EVENTMSGACTIONTYPE = 2`, the code will produce an output of `3PT_JUMP_SHOT = 1`
#
# Let's see it in action...

# %%
#Mapping out all of the EventMsgActionTypes for EventMsgType 2
import re
import operator

#the following expression is specific to EventMsgType 1
p = re.compile('(\s{2}|\' )([\w+ ]*)')

#get the PlayByPlay data from the Pacers game_id
plays = playbyplay.PlayByPlay(game_id).get_normalized_dict()['PlayByPlay']

#declare a few variables
description = ''
event_msg_action_types = {}

#loop over the play by play data
#do a bit of findall(regex) and a little character magic: underscores and upper case
#we're using a findall here as we have to deal with the extra word MISS at the beginning of the text.
#that extra text means we'll have multiple matches for our regex.
for play in plays:
    if play['EVENTMSGTYPE'] == 2:
        match = list()
        if play['HOMEDESCRIPTION'] is not None: 
            match = p.findall(play['HOMEDESCRIPTION'])
        
        if not match:
            match = p.findall(play['VISITORDESCRIPTION'])

        event_msg_action = re.sub(' ', '_', match[0][1]).upper()
        event_msg_action_types[event_msg_action] = play['EVENTMSGACTIONTYPE']
        
       # if play['EVENTMSGACTIONTYPE']
        
event_msg_action_types = sorted(event_msg_action_types.items(), key=operator.itemgetter(0))

for action in event_msg_action_types:
    print(f'\t{action[0]} = {action[1]}')

# %% [markdown]
# # What About Blocks?
# So if you've taken a close look at the data, especially that where `EVENTMSGTYPE == 2` you may have noticed that a few of the missed field goals were due to some incredible shot blocking players. By adding a few lines of code, we can find these shot blockers. Dealing with this data is a bit beyond the scope of this notebook, but it's worth pointing out that the data is in there. One idea is to play it into it's own play by play block (just a thought).

# %%
#Blocks are not included in the event feed but are a part of the EVENTMSGTYPE 2
import re
import operator

print('------------------')

#the following expression is specific to EventMsgType 1
p = re.compile('(\s{2}|\' )([\w+ ]*)')

#get the PlayByPlay data from the Pacers game_id
plays = playbyplay.PlayByPlay(game_id).get_normalized_dict()['PlayByPlay']

#declare a few variables
description = ''
event_msg_action_types = {}

#loop over the play by play data
#do a bit of findall(regex) and a little character magic: underscores and upper case
#we're using a findall here as we have to deal with the extra word MISS at the beginning of the text.
#that extra text means we'll have multiple matches for our regex.
for play in plays:
    if play['EVENTMSGTYPE'] == 2:
        match = list()
        if play['HOMEDESCRIPTION'] is not None: 
            match = p.findall(play['HOMEDESCRIPTION'])

            #looking for blocks
            if len(match) & (play['VISITORDESCRIPTION'] is not None):
                print(play['VISITORDESCRIPTION'])

        if not match:
            match = p.findall(play['VISITORDESCRIPTION'])
            
            #looking for blocks
            if len(match) & (play['HOMEDESCRIPTION'] is not None):
                print(play['HOMEDESCRIPTION'])


        event_msg_action = re.sub(' ', '_', match[0][1]).upper()
        event_msg_action_types[event_msg_action] = play['EVENTMSGACTIONTYPE']
            
event_msg_action_types = sorted(event_msg_action_types.items(), key=operator.itemgetter(0))

print('------------------')
