# %%
import os
import time
import pandas as pd
from nba_api.stats.endpoints import leaguegamefinder, boxscoretraditionalv2
from requests.exceptions import ReadTimeout, ConnectionError

# 定义计算 Possessions 的函数
def calculate_possessions(fga, fta, orb, tov, opp_fga, opp_fta, opp_orb, opp_tov):
    possessions = 0.5 * ((fga + 0.4 * fta - orb + tov) + (opp_fga + 0.4 * opp_fta - opp_orb + opp_tov))
    return possessions

# 获取 2023-24 赛季的常规赛比赛信息
def get_all_games(season='2023-24'):
    print("Fetching all games...")
    gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable=season, season_type_nullable='Regular Season')
    games = gamefinder.get_data_frames()[0]

    # 打印列名，确保正确
    print("Columns in the games data:", games.columns)

    # 过滤仅包含 2023-24 赛季的常规赛
    games = games[games['SEASON_ID'].astype(str).str.endswith('2023')]

    # 删除重复的比赛记录（基于 GAME_ID）
    games = games.drop_duplicates(subset=['GAME_ID'])

    # 过滤掉异常的MATCHUP（只保留NBA常规赛球队）
    valid_teams = ['ATL', 'BOS', 'BKN', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 
                   'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 
                   'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 
                   'TOR', 'UTA', 'WAS']
    games = games[games['MATCHUP'].str[:3].isin(valid_teams)]

    print(f"Filtered regular season games count: {len(games)}")
    return games


# 获取比赛统计数据并计算 possessions，同时存储数据
def get_game_stats_and_possessions(games, output_file='game_data.csv'):
    # 检查是否已有保存数据，避免重复抓取
    if os.path.exists(output_file):
        saved_data = pd.read_csv(output_file)
        saved_game_ids = set(saved_data['GAME_ID'])
        print(f"{len(saved_game_ids)} games already saved. Skipping these games...")
    else:
        saved_data = pd.DataFrame()
        saved_game_ids = set()

    all_game_data = []
    for _, row in games.iterrows():
        game_id = row['GAME_ID']

        if game_id in saved_game_ids:
            continue  # 跳过已保存的比赛

        try:
            for attempt in range(3):  # 最多尝试3次
                try:
                    time.sleep(1)  # 添加延迟，防止触发限流
                    boxscore = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id, timeout=60)
                    break  # 请求成功，跳出重试循环
                except (ReadTimeout, ConnectionError) as e:
                    print(f"Error fetching game {game_id}: {e}. Retrying... (Attempt {attempt + 1})")
                    time.sleep(5)  # 失败后等待 5 秒再尝试
            else:
                print(f"Failed to fetch data for game {game_id} after 3 attempts.")
                continue

            # 获取 team stats 数据（两支球队的统计数据）
            game_data = boxscore.get_data_frames()[1]
            team_stats = game_data[['TEAM_ID', 'FGA', 'FTA', 'OREB', 'TO', 'PTS']]

            # 分割成两队数据
            team1 = team_stats.iloc[0]
            team2 = team_stats.iloc[1]

            # 计算 Possessions
            possessions = calculate_possessions(
                team1['FGA'], team1['FTA'], team1['OREB'], team1['TO'],
                team2['FGA'], team2['FTA'], team2['OREB'], team2['TO']
            )

            # 将比赛信息转换为字典，并添加 Possessions
            row_data = row.to_dict()
            row_data['POSSESSIONS'] = possessions
            all_game_data.append(row_data)

            # 立即将数据保存到 CSV，防止中途出错丢失数据
            pd.DataFrame([row_data]).to_csv(output_file, mode='a', header=not os.path.exists(output_file), index=False)

        except Exception as e:
            print(f"Error processing game {game_id}: {e}")

    return pd.DataFrame(all_game_data)

# 批量处理比赛，防止一次性请求过多导致失败
def process_games_in_batches(games, batch_size=100, output_file='game_data.csv'):
    total_games = len(games)
    all_game_data = []
    for start_idx in range(0, total_games, batch_size):
        end_idx = min(start_idx + batch_size, total_games)
        batch_games = games.iloc[start_idx:end_idx]
        print(f"Processing games {start_idx + 1} to {end_idx}...")
        batch_data = get_game_stats_and_possessions(batch_games, output_file=output_file)
        all_game_data.append(batch_data)
        time.sleep(10)  # 每批次请求完成后暂停 10 秒，防止限流
    return pd.concat(all_game_data, ignore_index=True)

# 主程序执行
if __name__ == "__main__":
    output_file = 'game_data.csv'  # 保存的本地文件
    games = get_all_games()  # 获取所有常规赛比赛
    possession_data = process_games_in_batches(games, output_file=output_file)
    print(f"Data saved to {output_file}")
# Out:
# Fetching all games...
# Columns in the games data: Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')
# Filtered regular season games count: 1230
# Processing games 1 to 100...
# Processing games 101 to 200...
# 100 games already saved. Skipping these games...
# Processing games 201 to 300...
# 200 games already saved. Skipping these games...
# Processing games 301 to 400...
# 300 games already saved. Skipping these games...
# Processing games 401 to 500...
# 400 games already saved. Skipping these games...
# Processing games 501 to 600...
# 500 games already saved. Skipping these games...
# Processing games 601 to 700...
# 600 games already saved. Skipping these games...
# Error fetching game 0022300604: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60). Retrying... (Attempt 1)
# Error fetching game 0022300604: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying... (Attempt 2)
# Error fetching game 0022300604: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=60). Retrying... (Attempt 3)
# Failed to fetch data for game 0022300604 after 3 attempts.
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File D:\Anaconda\Lib\http\client.py:1386, in HTTPConnection.getresponse(self)
#    1385 try:
# -> 1386     response.begin()
#    1387 except ConnectionError:
#
# File D:\Anaconda\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File D:\Anaconda\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#
# File D:\Anaconda\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File D:\Anaconda\Lib\ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#
# File D:\Anaconda\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1166 if buffer is not None:
# -> 1167     return self._sslobj.read(len, buffer)
#    1168 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 113
#     111 output_file = 'game_data.csv'  # 保存的本地文件
#     112 games = get_all_games()  # 获取所有常规赛比赛
# --> 113 possession_data = process_games_in_batches(games, output_file=output_file)
#     114 print(f"Data saved to {output_file}")
#
# Cell In[1], line 104, in process_games_in_batches(games, batch_size, output_file)
#     102 batch_games = games.iloc[start_idx:end_idx]
#     103 print(f"Processing games {start_idx + 1} to {end_idx}...")
# --> 104 batch_data = get_game_stats_and_possessions(batch_games, output_file=output_file)
#     105 all_game_data.append(batch_data)
#     106 time.sleep(10)  # 每批次请求完成后暂停 10 秒，防止限流
#
# Cell In[1], line 60, in get_game_stats_and_possessions(games, output_file)
#      58 try:
#      59     time.sleep(1)  # 添加延迟，防止触发限流
# ---> 60     boxscore = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id, timeout=60)
#      61     break  # 请求成功，跳出重试循环
#      62 except (ReadTimeout, ConnectionError) as e:
#
# File D:\Anaconda\Lib\site-packages\nba_api\stats\endpoints\boxscoretraditionalv2.py:133, in BoxScoreTraditionalV2.__init__(self, game_id, end_period, end_range, range_type, start_period, start_range, proxy, headers, timeout, get_request)
#     124 self.parameters = {
#     125     "GameID": game_id,
#     126     "EndPeriod": end_period,
#    (...)
#     130     "StartRange": start_range,
#     131 }
#     132 if get_request:
# --> 133     self.get_request()
#
# File D:\Anaconda\Lib\site-packages\nba_api\stats\endpoints\boxscoretraditionalv2.py:136, in BoxScoreTraditionalV2.get_request(self)
#     135 def get_request(self):
# --> 136     self.nba_response = NBAStatsHTTP().send_api_request(
#     137         endpoint=self.endpoint,
#     138         parameters=self.parameters,
#     139         proxy=self.proxy,
#     140         headers=self.headers,
#     141         timeout=self.timeout,
#     142     )
#     143     self.load_response()
#
# File D:\Anaconda\Lib\site-packages\nba_api\library\http.py:160, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     157         print("loading from file...")
#     159 if not contents:
# --> 160     response = self.get_session().get(
#     161         url=base_url,
#     162         params=parameters,
#     163         headers=request_headers,
#     164         proxies=proxies,
#     165         timeout=timeout,
#     166     )
#     167     url = response.url
#     168     status_code = response.status_code
#
# File D:\Anaconda\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File D:\Anaconda\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File D:\Anaconda\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File D:\Anaconda\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File D:\Anaconda\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File D:\Anaconda\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File D:\Anaconda\Lib\http\client.py:1402, in HTTPConnection.getresponse(self)
#    1400     return response
#    1401 except:
# -> 1402     response.close()
#    1403     raise
#
# File D:\Anaconda\Lib\http\client.py:424, in HTTPResponse.close(self)
#     421     self.fp = None
#     422     fp.close()
# --> 424 def close(self):
#     425     try:
#     426         super().close() # set "closed" flag
#
# KeyboardInterrupt:
